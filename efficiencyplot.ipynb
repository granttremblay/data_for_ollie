# %%
from astropy.io import ascii
import pandas as pd
# import seaborn as sns

from matplotlib import pyplot as plt

# %config InlineBackend.figure_format='retina'

# %%
import pandas as pd

df = pd.read_excel(
    "chdr_mission_efficiency.xlsx",
    parse_dates=[2],
)
# df = pd.read_excel("FOTMP_mission_efficiency.xlsx")
df
# Out:
#       Unnamed: 0 Unnamed: 1           Unnamed: 2  science orbit efficiency  \
# 0         2000.0        NaN  2000-07-02 00:00:00                  0.896832
# 1            NaN        NaN  2000-07-09 00:00:00                  0.927505
# 2            NaN        NaN  2000-07-16 00:00:00                  0.951513
# 3            NaN        NaN  2000-07-23 00:00:00                  0.910541
# 4            NaN        NaN  2000-07-30 00:00:00                  0.931126
# ...          ...        ...                  ...                       ...
# 1206         NaN   FEB1924A             02/19/24                  0.858236
# 1207         NaN   FEB2624A             02/26/24                  0.877659
# 1208         NaN   MAR0424A             03/04/24                  0.855317
# 1209         NaN   MAR0624A             03/06/24                  0.832347
# 1210         NaN   MAR1124A             03/11/24                  0.870989
#
# ...

# %%
# df = pd.read_excel(
#     "chdr_mission_efficiency.xlsx",
#     parse_dates=[2],
#     names=[
#         "Year",
#         "Load",
#         "Date",
#         "Science Orbit Efficiency",
#         "Available Science Percentage",
#         "Overall Efficiency",
#     ],
# )
# df
# Out:
#                                                   Year      Load Date  \
# 2000.0 NaN      2000-07-02 00:00:00 0.896832  0.641818  0.715650  NaT
# NaN    NaN      2000-07-09 00:00:00 0.927505  0.742948  0.801017  NaT
#                 2000-07-16 00:00:00 0.951513  0.708542  0.744648  NaT
#                 2000-07-23 00:00:00 0.910541  0.650631  0.714554  NaT
#                 2000-07-30 00:00:00 0.931126  0.746520  0.801739  NaT
# ...                                                ...       ...  ...
#        FEB1924A 02/19/24            0.858236  0.719757  0.838646  NaT
#        FEB2624A 02/26/24            0.877659  0.720707  0.821169  NaT
#        MAR0424A 03/04/24            0.855317  0.689414  0.806034  NaT
#        MAR0624A 03/06/24            0.832347  0.684403  0.822257  NaT
#        MAR1124A 03/11/24            0.870989  0.742774  0.852794  NaT
#
#                                               Science Orbit Efficiency  \
# ...

# %%
df["Overall Efficiency (Moving Average)"] = (
    df["overall efficiency"].rolling(window=7, min_periods=1).mean()
)
df
# Out:
#       Unnamed: 0 Unnamed: 1           Unnamed: 2  science orbit efficiency  \
# 0         2000.0        NaN  2000-07-02 00:00:00                  0.896832
# 1            NaN        NaN  2000-07-09 00:00:00                  0.927505
# 2            NaN        NaN  2000-07-16 00:00:00                  0.951513
# 3            NaN        NaN  2000-07-23 00:00:00                  0.910541
# 4            NaN        NaN  2000-07-30 00:00:00                  0.931126
# ...          ...        ...                  ...                       ...
# 1206         NaN   FEB1924A             02/19/24                  0.858236
# 1207         NaN   FEB2624A             02/26/24                  0.877659
# 1208         NaN   MAR0424A             03/04/24                  0.855317
# 1209         NaN   MAR0624A             03/06/24                  0.832347
# 1210         NaN   MAR1124A             03/11/24                  0.870989
#
# ...

# %%
plt.style.use("ggplot")

# %%
fig, ax = plt.subplots(figsize=(12, 8))
# ax.plot_date(df['Date'], df['Available Science Percentage'] * 100,  label='Available Science Percentage')
# ax.plot_date(df["Date"], df["overall efficiency"] * 100, label="Overall Efficiency")
# ax.plot_date(
ax.plot(
    # df["Date"],
    df["Overall Efficiency (Moving Average)"] * 100,
    "b-",
    label="Moving Average",
)
